# %%
{
    "search_metadata": {
        "id": "691e191af9aa73d128e07edc",
        "status": "Success",
        "json_endpoint": "https://serpapi.com/searches/c8a740525180888e/691e191af9aa73d128e07edc.json",
        "pixel_position_endpoint": "https://serpapi.com/searches/c8a740525180888e/691e191af9aa73d128e07edc.json_with_pixel_position",
        "created_at": "2025-11-19 19:23:06 UTC",
        "processed_at": "2025-11-19 19:23:06 UTC",
        "google_url": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1%3F&oq=What+are+new+features+of+langchain+v1%3F&sourceid=chrome&ie=UTF-8",
        "raw_html_file": "https://serpapi.com/searches/c8a740525180888e/691e191af9aa73d128e07edc.html",
        "total_time_taken": 2.01,
    },
    "search_parameters": {
        "engine": "google",
        "q": "What are new features of langchain v1?",
        "google_domain": "google.com",
        "device": "desktop",
    },
    "search_information": {
        "query_displayed": "What are new features of langchain v1?",
        "organic_results_state": "Results for exact spelling",
    },
    "inline_images": [
        {
            "source": "https://docs.langchain.com/oss/python/releases/langchain-v1",
            "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR9CZlO84rUuz2WDAye26thBzhIzZsAnzdHB2D2XDgw1xUhgnyn8-fAVPg&s",
            "original": "https://langchain-5e9cc07a.mintlify.app/mintlify-assets/_next/image?url=%2F_mintlify%2Fapi%2Fog%3Fdivision%3DLangChain%2Bv1.0%26appearance%3Dsystem%26title%3DWhat%2527s%2Bnew%2Bin%2Bv1%26logoLight%3Dhttps%253A%252F%252Fmintcdn.com%252Flangchain-5e9cc07a%252FXbr8HuVd9jPi6qTU%252Fimages%252Fbrand%252Flangchain-docs-teal.svg%253Ffit%253Dmax%2526auto%253Dformat%2526n%253DXbr8HuVd9jPi6qTU%2526q%253D85%2526s%253D16111530672bf976cb54ef2143478342%26logoDark%3Dhttps%253A%252F%252Fmintcdn.com%252Flangchain-5e9cc07a%252FXbr8HuVd9jPi6qTU%252Fimages%252Fbrand%252Flangchain-docs-lilac.svg%253Ffit%253Dmax%2526auto%253Dformat%2526n%253DXbr8HuVd9jPi6qTU%2526q%253D85%2526s%253Db70fb1a2208670492ef94aef14b680be%26primaryColor%3D%25232F6868%26lightColor%3D%252384C4C0%26darkColor%3D%25231C3C3C%26backgroundLight%3D%2523ffffff%26backgroundDark%3D%25230b0d0f&w=1200&q=100",
            "title": "What's new in v1 - Docs by LangChain",
            "source_name": "LangChain Docs",
        },
        {
            "source": "https://www.youtube.com/watch?v=slJlB-woA4Q",
            "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-6JXT_9-4VUqlGS8XkpxojH6O8Ncgv_v2fR1BHCG1x_-AYIr5gN_hcX0&s",
            "original": "https://i.ytimg.com/vi/slJlB-woA4Q/maxresdefault.jpg",
            "title": "LangChain v1: What JS and Python developers need to know",
            "source_name": "YouTube",
        },
        {
            "source": "https://www.youtube.com/watch?v=H_sopaKXyVU",
            "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHn4z-3SKasr0HmyabpORFmMGmPixj62W4mcpIxV9xx7l8o12SkJhl-No&s",
            "original": "https://i.ytimg.com/vi/H_sopaKXyVU/hq720.jpg?sqp=-oaymwEhCK4FEIIDSFryq4qpAxMIARUAAAAAGAElAADIQj0AgKJD&rs=AOn4CLBqmLaAAm67KDaaUER5TP5u-pAofQ",
            "title": "Langchain v1 Agents 6 - String vs SystemMessage in LangChain",
            "source_name": "YouTube",
        },
    ],
    "inline_videos": [
        {
            "position": 1,
            "title": "LangChain v1.0 Upgrade Guide — What's New and What Broke!",
            "link": "https://www.youtube.com/watch?v=SUzfebcOhiU",
            "thumbnail": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/6742a05cf6341fc9354388275cb0c09210965a9f76156b2ae289fe9d4cef4d1e.jpeg",
            "channel": "Execute Automation",
            "duration": "11:44",
            "platform": "YouTube",
        },
        {
            "position": 2,
            "title": "LangChain Reaches 1.0 - Whats new?",
            "link": "https://www.youtube.com/watch?v=hjIlj4OAECQ",
            "thumbnail": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/6742a05cf6341fc95ac31903296a03e2de6bfa367f6682574555a65f250b2cc6.jpeg",
            "channel": "Sam Witteveen",
            "duration": "16:35",
            "platform": "YouTube",
        },
        {
            "position": 3,
            "title": "LangChain v1.0 alpha: Review and What has Changed : r ...",
            "link": "https://www.reddit.com/r/LangChain/comments/1nbs8l2/langchain_v10_alpha_review_and_what_has_changed/",
            "thumbnail": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/6742a05cf6341fc9d9520143518f5fd6f108cf68da1f9354cadaeb54fba9b9bb.jpeg",
            "channel": "Agenta AI",
            "duration": "9:17",
            "platform": "Reddit",
        },
        {
            "position": 4,
            "title": "LangChain v1 Just BLEW MY MIND (Create Agent is INSANE!)",
            "link": "https://www.youtube.com/watch?v=G-HL5mRyYQc",
            "thumbnail": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/6742a05cf6341fc9b0a6a0735066621fd9d97af4f969e0435d1f7317b89aac33.jpeg",
            "channel": "Prompt Engineer",
            "duration": "18:53",
            "platform": "YouTube",
        },
    ],
    "related_questions": [
        {
            "question": "What's new in LangChain?",
            "type": "featured_snippet",
            "next_page_token": "...",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...",
        },
        {
            "question": "Why are developers quitting LangChain?",
            "type": "featured_snippet",
            "next_page_token": "...",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D",
        },
        {
            "question": "What are the key features of LangChain?",
            "type": "featured_snippet",
            "next_page_token": "...",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D",
        },
        {
            "question": "Is LangChain being deprecated?",
            "type": "featured_snippet",
            "next_page_token": "...",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D",
        },
    ],
    "ai_overview": {
        "page_token": "YmSkTXicxZTdkqI4FMev90GGG3sFbD-wq6ipEOgWHUG6ZRy9sSJisBHSEhCZu3mXfap9mgn4AdpO18zF1oYqQsjJyf-c_HJ-_LNZh_6_f029OH6jDzyfpmkdE4I3bt0hAY9oFjr8imxo5Hifs518zzlUFjh3LT_tfRc5f_e01stzuvBH2Zc2aQOJK5bI8wWi7ivzuH-l_JxnL__TvcoGdVp3w3riTWzdj6GXkXpDELt1k0cBMwD_YVMAwDrrbcg-Kv_ZtwaAVTXVq6uKGazo4EbTqv599oKQ-StMB9e2Vmn-ooMeWM1jVS2FKO98nyXBNFcwACnzocDLXd_pOPiBx4F1w3Fl_kofAOYNjxctD2t6GpA83h5TB4tN1MKJd5hLiIbPm_tgBJqp5tib216ZJYHmDEh4CG9IO0qCA6oHooKBxi8xo0XgFxHrRD6iOTtw3BVIL5V8SUyolN4vrNlCep7se93gPvkaEHxXUOnQM5a0iqXp9_eZG7ZUQap_qStihck8GdaVLsieXyXpo1Y5jhIpLT-QvuWdxgKgLNUlkykwGLvW7OxEL98f7pIrhKVQxgO-NISVGLRioarkJgczWFBhncSq-HRDC9gPzboICefbnW_TmRQdKJRdDagrTEPORVquKRXphQALl8M86aalHAOyigv8JAFsaQdxsLBQAGQq9CIdBF7kWD2j_ogZk_5V-L_VyEeT-g0ItSQgbz0zVCfaABlDp6n5XTuK_JHppUcISbD4g-Lo_L-YlqWTneElptoVpqTEVAHP-aKPSudxl1Pp9I-l8xpTq8S0LJ3eGVPlGlN_fIoiuF06K5jmf6YnwVeYKrcwhe8xtS4w1X6B6YBhOi0xhVCplk54LJ1nTP-4dNLfLJ0Fre6hu6yjySt-h7I21JCvO83OUNqaWee57QpJsjDGNAJ381UQP6Dl5m6-Xj4ojX6cLbmtPPFQXEORWwvdtLZyUZxELq2RVW2DQux4aB3WduJnLthERBZQxxh1wWRsmIHZmZHdevE0dubDQfASzfVRZDexmYZLZzhTIeoH-8fdY7Rp2d8tugSJ6Nm97510bvTCgaRh2uhKreaqbfd1b7jtwK_bp51jmOs4QjZqS8EQrf3-JlPdBpiMYCMepf30265pj7be4tt0ncGXcF-oojJ4HUQrnRr9NuUCtKSuLHJB5MgswU0fGBawOOqguUt3cqvVkqTVUmgJorhsSg0uwHH2JjdFjoaRLP4EAMyw_A",
        "serpapi_link": "https://serpapi.com/search.json?engine=google_ai_overview&page_token=YmSkTXicxZTdkqI4FMev90GGG3sFbD-wq6ipEOgWHUG6ZRy9sSJisBHSEhCZu3mXfap9mgn4AdpO18zF1oYqQsjJyf-c_HJ-_LNZh_6_f029OH6jDzyfpmkdE4I3bt0hAY9oFjr8imxo5Hifs518zzlUFjh3LT_tfRc5f_e01stzuvBH2Zc2aQOJK5bI8wWi7ivzuH-l_JxnL__TvcoGdVp3w3riTWzdj6GXkXpDELt1k0cBMwD_YVMAwDrrbcg-Kv_ZtwaAVTXVq6uKGazo4EbTqv599oKQ-StMB9e2Vmn-ooMeWM1jVS2FKO98nyXBNFcwACnzocDLXd_pOPiBx4F1w3Fl_kofAOYNjxctD2t6GpA83h5TB4tN1MKJd5hLiIbPm_tgBJqp5tib216ZJYHmDEh4CG9IO0qCA6oHooKBxi8xo0XgFxHrRD6iOTtw3BVIL5V8SUyolN4vrNlCep7se93gPvkaEHxXUOnQM5a0iqXp9_eZG7ZUQap_qStihck8GdaVLsieXyXpo1Y5jhIpLT-QvuWdxgKgLNUlkykwGLvW7OxEL98f7pIrhKVQxgO-NISVGLRioarkJgczWFBhncSq-HRDC9gPzboICefbnW_TmRQdKJRdDagrTEPORVquKRXphQALl8M86aalHAOyigv8JAFsaQdxsLBQAGQq9CIdBF7kWD2j_ogZk_5V-L_VyEeT-g0ItSQgbz0zVCfaABlDp6n5XTuK_JHppUcISbD4g-Lo_L-YlqWTneElptoVpqTEVAHP-aKPSudxl1Pp9I-l8xpTq8S0LJ3eGVPlGlN_fIoiuF06K5jmf6YnwVeYKrcwhe8xtS4w1X6B6YBhOi0xhVCplk54LJ1nTP-4dNLfLJ0Fre6hu6yjySt-h7I21JCvO83OUNqaWee57QpJsjDGNAJ381UQP6Dl5m6-Xj4ojX6cLbmtPPFQXEORWwvdtLZyUZxELq2RVW2DQux4aB3WduJnLthERBZQxxh1wWRsmIHZmZHdevE0dubDQfASzfVRZDexmYZLZzhTIeoH-8fdY7Rp2d8tugSJ6Nm97510bvTCgaRh2uhKreaqbfd1b7jtwK_bp51jmOs4QjZqS8EQrf3-JlPdBpiMYCMepf30265pj7be4tt0ncGXcF-oojJ4HUQrnRr9NuUCtKSuLHJB5MgswU0fGBawOOqguUt3cqvVkqTVUmgJorhsSg0uwHH2JjdFjoaRLP4EAMyw_A",
    },
    "organic_results": [
        {
            "position": 1,
            "title": "What's new in v1 - Docs by LangChain",
            "link": "https://docs.langchain.com/oss/javascript/releases/langchain-v1",
            "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://docs.langchain.com/oss/javascript/releases/langchain-v1&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0QFnoECBwQAQ",
            "displayed_link": "https://docs.langchain.com › oss › javascript › releases",
            "favicon": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/e25481f14419ff60ff5ae666e2e53a2872f4d8f227ef7a8e6bb5d3bce2856a58.png",
            "snippet": "What's new in v1 · Main loop integration: Structured output is now generated in the main loop instead of requiring an additional LLM call · Parsing errors ...",
            "snippet_highlighted_words": ["Main loop integration"],
            "source": "LangChain",
        },
        {
            "position": 2,
            "title": "What's new in v1 - Docs by LangChain",
            "link": "https://docs.langchain.com/oss/python/releases/langchain-v1",
            "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://docs.langchain.com/oss/python/releases/langchain-v1&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0QFnoECB0QAQ",
            "displayed_link": "https://docs.langchain.com › oss › python › releases › l...",
            "favicon": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/e25481f14419ff60ff5ae666e2e53a28c93c7e40527b047b114de00689b9649e.png",
            "snippet": "Main loop integration: Structured output is now generated in the main loop instead of requiring an additional LLM call · Parsing errors · Provider agnostic: ...",
            "snippet_highlighted_words": ["Main loop integration"],
            "sitelinks": {
                "inline": [
                    {
                        "title": "Prebuilt middleware",
                        "link": "https://docs.langchain.com/oss/python/releases/langchain-v1#prebuilt-middleware",
                    },
                    {
                        "title": "Custom middleware",
                        "link": "https://docs.langchain.com/oss/python/releases/langchain-v1#custom-middleware",
                    },
                    {
                        "title": "Structured output",
                        "link": "https://docs.langchain.com/oss/python/releases/langchain-v1#structured-output",
                    },
                    {
                        "title": "Namespace",
                        "link": "https://docs.langchain.com/oss/python/releases/langchain-v1#namespace",
                    },
                ]
            },
            "source": "LangChain",
        },
        {
            "position": 3,
            "title": "LangChain and LangGraph v1.0: Beyond Release Notes ...",
            "link": "https://agentissue.medium.com/langchain-and-langgraph-v1-0-beyond-release-notes-into-real-roi-7538fc02ff83",
            "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://agentissue.medium.com/langchain-and-langgraph-v1-0-beyond-release-notes-into-real-roi-7538fc02ff83&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0QFnoECEAQAQ",
            "displayed_link": "6 likes · 3 weeks ago",
            "thumbnail": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/e25481f14419ff60ff5ae666e2e53a28fd74646bcb8c1997b4af316595ff3e69.jpeg",
            "favicon": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/e25481f14419ff60ff5ae666e2e53a28f66519e65265089e9fef874adee10d16.png",
            "snippet": "LangChain 1.0 is a major refinement of the library, focusing on the core agent loop , flexibility via middleware , and updated model integration ...",
            "snippet_highlighted_words": ["loop"],
            "source": "Medium · Agent Native",
        },
        {
            "position": 4,
            "title": "What's new in v1 - Docs by LangChain",
            "link": "https://docs.langchain.com/oss/python/releases/langgraph-v1",
            "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://docs.langchain.com/oss/python/releases/langgraph-v1&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0QFnoECC8QAQ",
            "displayed_link": "https://docs.langchain.com › releases › langgraph-v1",
            "favicon": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/e25481f14419ff60ff5ae666e2e53a28a57bb50b466540ca65bdb116e7130db0.png",
            "snippet": "What's new in v1 · Stable core APIs. Graph primitives (state, nodes, edges) and the execution/runtime model are unchanged, making upgrades straightforward.",
            "snippet_highlighted_words": ["Stable core APIs"],
            "source": "LangChain",
        },
        {
            "position": 5,
            "title": "LangChain v1 is now generally available!",
            "link": "https://techcommunity.microsoft.com/blog/azuredevcommunityblog/langchain-v1-is-now-generally-available/4462159",
            "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://techcommunity.microsoft.com/blog/azuredevcommunityblog/langchain-v1-is-now-generally-available/4462159&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0QFnoECDAQAQ",
            "displayed_link": "https://techcommunity.microsoft.com › blog › langchai...",
            "favicon": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/e25481f14419ff60ff5ae666e2e53a284bb7b487ff47265ea1d6677d15b81ba9.png",
            "date": "Oct 17, 2025",
            "snippet": "New middleware such as 'human in the loop' and 'summarization' middleware have been added. This is a feature of the new package that I am most ...",
            "snippet_highlighted_words": ["New", "feature", "new"],
            "source": "Microsoft Community Hub",
        },
        {
            "position": 6,
            "title": "LangChain Middleware v1-Alpha: A Comprehensive Guide to ...",
            "link": "https://colinmcnamara.com/blog/langchain-middleware-v1-alpha-guide",
            "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://colinmcnamara.com/blog/langchain-middleware-v1-alpha-guide&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0QFnoECDEQAQ",
            "displayed_link": "https://colinmcnamara.com › blog › langchain-middlew...",
            "favicon": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/e25481f14419ff60ff5ae666e2e53a2801cc3c71ef8c8cc324136364ebe9e048.png",
            "date": "Sep 16, 2025",
            "snippet": "LangChain's v1-alpha release introduces a revolutionary middleware system that fundamentally transforms how developers interact with and control ...",
            "snippet_highlighted_words": ["LangChain's v1"],
            "source": "colinmcnamara.com",
        },
        {
            "position": 7,
            "title": "LangChain and LangGraph 1.0: New Docs, Agent ...",
            "link": "https://www.linkedin.com/posts/harrison-chase-961287118_announcing-langchain-and-langgraph-10-activity-7386795886137434114--AC0",
            "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.linkedin.com/posts/harrison-chase-961287118_announcing-langchain-and-langgraph-10-activity-7386795886137434114--AC0&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0QFnoECDIQAQ",
            "displayed_link": "1.3K+ reactions · 4 weeks ago",
            "favicon": "https://serpapi.com/searches/691e191af9aa73d128e07edc/images/e25481f14419ff60ff5ae666e2e53a28a07bd8cb633ade28195a6a4c371a66dc.png",
            "snippet": "It is now production ready. • LangChain is more flexible than ever with a new create_agent template, middleware for custom behavior, and ...",
            "snippet_highlighted_words": ["LangChain is more flexible than ever"],
            "source": "LinkedIn · Harrison Chase",
        },
    ],
    "perspectives": [
        {
            "author": "Execute Automation",
            "author_description": "Automation testing videos for free",
            "source": "YouTube",
            "extensions": ["840+ views "],
            "thumbnails": ["https://img.youtube.com/vi/SUzfebcOhiU/hqdefault.jpg"],
            "title": "LangChain v1.0 Upgrade Guide — What’s New and What Broke!",
            "link": "https://www.youtube.com/watch?v=SUzfebcOhiU",
            "date": "2 weeks ago",
            "video": "https://encrypted-vtbn0.gstatic.com/video?q=tbn:ANd9GcS734oWrL4WZb8POxRZXngN4cEPOylc4PUbPw",
        },
        {
            "author": "Prompt Engineer",
            "author_description": "AI & ML commentator",
            "source": "YouTube",
            "extensions": ["1.8K+ views "],
            "thumbnails": ["https://img.youtube.com/vi/G-HL5mRyYQc/hqdefault.jpg"],
            "title": "LangChain v1 Just BLEW MY MIND 🤯 (Create Agent is INSANE!)",
            "link": "https://www.youtube.com/watch?v=G-HL5mRyYQc",
            "date": "3 weeks ago",
            "video": "https://encrypted-vtbn0.gstatic.com/video?q=tbn:ANd9GcQ5gERvA_odGo3E-Xpg7L3cK_Mw_QLiLEv7Sg",
        },
        {
            "author": "Sam Witteveen",
            "author_description": "Machine learning engineer",
            "source": "YouTube",
            "extensions": ["18K+ views "],
            "thumbnails": ["https://img.youtube.com/vi/hjIlj4OAECQ/hqdefault.jpg"],
            "title": "LangChain Reaches 1.0 - Whats new?",
            "link": "https://www.youtube.com/watch?v=hjIlj4OAECQ",
            "date": "3 weeks ago",
            "video": "https://encrypted-vtbn0.gstatic.com/video?q=tbn:ANd9GcQRqe3i1082wAvae_hYKbVwwqu_gbiFNsUk_w",
        },
    ],
    "related_searches": [
        {
            "block_position": 1,
            "query": "What are new features of langchain v1 reddit",
            "link": "https://www.google.com/search?sca_esv=55588fd05011d482&q=What+are+new+features+of+langchain+v1+reddit&sa=X&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q1QJ6BAguEAE",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1+reddit",
        },
        {
            "block_position": 1,
            "query": "What are new features of langchain v1 github",
            "link": "https://www.google.com/search?sca_esv=55588fd05011d482&q=What+are+new+features+of+langchain+v1+github&sa=X&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q1QJ6BAhEEAE",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1+github",
        },
        {
            "block_position": 1,
            "query": "Langchain v1 0 release date",
            "link": "https://www.google.com/search?sca_esv=55588fd05011d482&q=Langchain+v1+0+release+date&sa=X&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q1QJ6BAhDEAE",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Langchain+v1+0+release+date",
        },
        {
            "block_position": 1,
            "query": "Langchain 1.0 GitHub",
            "link": "https://www.google.com/search?sca_esv=55588fd05011d482&q=Langchain+1.0+GitHub&sa=X&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q1QJ6BAhBEAE",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Langchain+1.0+GitHub",
        },
        {
            "block_position": 1,
            "query": "Langchain js v1",
            "link": "https://www.google.com/search?sca_esv=55588fd05011d482&q=Langchain+js+v1&sa=X&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q1QJ6BAg_EAE",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Langchain+js+v1",
        },
        {
            "block_position": 1,
            "query": "Langchain classic pip",
            "link": "https://www.google.com/search?sca_esv=55588fd05011d482&q=Langchain+classic+pip&sa=X&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q1QJ6BAg6EAE",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Langchain+classic+pip",
        },
        {
            "block_position": 1,
            "query": "LangChain 1.0 tutorial",
            "link": "https://www.google.com/search?sca_esv=55588fd05011d482&q=LangChain+1.0+tutorial&sa=X&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q1QJ6BAg1EAE",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=LangChain+1.0+tutorial",
        },
        {
            "block_position": 1,
            "query": "LangChain latest version",
            "link": "https://www.google.com/search?sca_esv=55588fd05011d482&q=LangChain+latest+version&sa=X&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q1QJ6BAgzEAE",
            "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=LangChain+latest+version",
        },
    ],
    "pagination": {
        "current": 1,
        "next": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=10&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8NMDegQIZxAW",
        "other_pages": {
            "2": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=10&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAE",
            "3": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=20&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAG",
            "4": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=30&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAI",
            "5": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=40&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAK",
            "6": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=50&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAM",
            "7": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=60&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAO",
            "8": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=70&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAQ",
            "9": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=80&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAS",
            "10": "https://www.google.com/search?q=What+are+new+features+of+langchain+v1?&sca_esv=55588fd05011d482&ei=Gxkeac-HE5SRwbkPyL6o6A8&start=90&sa=N&sstk=Af77f_dGA9xqIQfRRRzq5XbqSpfsRG2hSlFNCqPl17687DYPi9J1aCay4jWkk7IEvjHK5IOZPtRnQjzQVUyN3s91XPkwZgDMWDR_hg&ved=2ahUKEwiPgeSU-P6QAxWUSDABHUgfCv0Q8tMDegQIZxAU",
        },
    },
    "serpapi_pagination": {
        "current": 1,
        "next_link": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=10",
        "next": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=10",
        "other_pages": {
            "2": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=10",
            "3": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=20",
            "4": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=30",
            "5": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=40",
            "6": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=50",
            "7": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=60",
            "8": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=70",
            "9": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=80",
            "10": "https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=What+are+new+features+of+langchain+v1%3F&start=90",
        },
    },
}
